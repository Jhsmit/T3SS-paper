# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from colicoords.preprocess import data_to_cells, filter_binaries
from colicoords import Data, iter_subplots, CellListPlot, IterCellPlot, AutoIterCellPlot, save
import os
import mahotas as mh
# Out:
# Warning: Version number not found.

# %%
import colicoords
colicoords.__file__
# Out:
# 'C:\\Users\\jhs\\Programming\\cc_master\\colicoords\\__init__.py'

# %%
#input_dir = r'F:\_processed_big\t3ss\20191002_deltaescv_c41_eyfp-escv_repeat_03'
input_dir = r'H:\20191002_deltaescv_c41_eyfp-escv_repeat_03'

# %%
c41_bf = np.load(os.path.join(input_dir, 'BF_C41_flat.npy'))
c41_bin = np.load(os.path.join(input_dir, 'c41_segmented.npy'))
c41_g100 = np.load(os.path.join(input_dir, 'c41_G100.npy'))
c41_g500 = np.load(os.path.join(input_dir, 'c41_G500.npy'))

# %%
c41_g500.shape
# Out:
# (1000, 512, 512)

# %%
c41_b_filter = filter_binaries(c41_bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(c41_b_filter, 'binary')
data.add_data(c41_bf, 'brightfield')
data.add_data(c41_g100, 'fluorescence', 'g100')
data.add_data(c41_g500, 'fluorescence', 'g500')

# %%
cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Cell 6 on image binary 0: on the edge of the image
# Cell 2 on image binary 4: on the edge of the image
# Image binary 7: No cells
# Cell 1 on image binary 10: on the edge of the image
# Image binary 12: No cells
# Image binary 14: No cells
# Image binary 18: No cells
# Image binary 20: No cells
# Image binary 22: No cells
# Image binary 25: No cells
# Cell 2 on image binary 26: on the edge of the image
# Image binary 28: No cells
# Image binary 31: No cells
# Image binary 32: No cells
# Image binary 33: No cells
# Image binary 34: No cells
# Image binary 35: No cells
# Image binary 36: No cells
# Image binary 37: No cells
# Image binary 38: No cells
# Image binary 39: No cells
# Image binary 40: No cells
# Image binary 42: No cells
# Image binary 43: No cells
# Image binary 45: No cells
# Image binary 46: No cells
# Image binary 49: No cells
# Image binary 50: No cells
# Image binary 51: No cells
# Image binary 54: No cells
# Image binary 56: No cells
# Image binary 58: No cells
# Image binary 63: No cells
# Image binary 64: No cells
# Cell 2 on image binary 67: on the edge of the image
# Image binary 68: No cells
# Image binary 69: No cells
# Cell 2 on image binary 81: on the edge of the image
# Cell 4 on image binary 84: on the edge of the image
# Image binary 86: No cells
# Image binary 87: No cells
# Image binary 90: No cells
# Cell 2 on image binary 92: on the edge of the image
# Image binary 101: No cells
# Image binary 102: No cells
# Image binary 103: No cells
# Image binary 106: No cells
# Image binary 108: No cells
# Image binary 109: No cells
# Image binary 110: No cells
# Image binary 112: No cells
# Image binary 113: No cells
# Image binary 116: No cells
# Image binary 118: No cells
# Image binary 121: No cells
# Image binary 125: No cells
# Image binary 126: No cells
# Image binary 127: No cells
# Image binary 128: No cells
# Image binary 129: No cells
# Image binary 130: No cells
# Image binary 132: No cells
# Image binary 133: No cells
# Image binary 134: No cells
# Image binary 135: No cells
# Image binary 136: No cells
# Cell 1 on image binary 137: on the edge of the image
# Image binary 139: No cells
# Image binary 140: No cells
# Image binary 142: No cells
# Image binary 144: No cells
# Image binary 145: No cells
# Image binary 146: No cells
# Image binary 149: No cells
# Cell 1 on image binary 152: on the edge of the image
# Cell 1 on image binary 154: on the edge of the image
# Cell 2 on image binary 155: on the edge of the image
# Image binary 160: No cells
# Image binary 165: No cells
# Image binary 166: No cells
# Cell 1 on image binary 168: on the edge of the image
# Cell 7 on image binary 168: on the edge of the image
# Cell 2 on image binary 174: on the edge of the image
# Cell 4 on image binary 174: on the edge of the image
# Image binary 175: No cells
# Image binary 181: No cells
# Image binary 186: No cells
# Cell 4 on image binary 189: on the edge of the image
# Image binary 190: No cells
# Image binary 191: No cells
# Image binary 199: No cells
# Image binary 203: No cells
# Cell 1 on image binary 204: on the edge of the image
# Image binary 206: No cells
# Cell 1 on image binary 207: on the edge of the image
# Image binary 224: No cells
# Cell 1 on image binary 225: on the edge of the image
# Image binary 226: No cells
# Image binary 228: No cells
# Image binary 243: No cells
# Cell 3 on image binary 244: on the edge of the image
# Cell 4 on image binary 244: on the edge of the image
# Image binary 256: No cells
# Cell 1 on image binary 257: on the edge of the image
# Image binary 261: No cells
# Image binary 264: No cells
# Cell 1 on image binary 269: on the edge of the image
# Image binary 272: No cells
# Image binary 277: No cells
# Image binary 278: No cells
# Image binary 280: No cells
# Image binary 281: No cells
# Image binary 286: No cells
# Cell 1 on image binary 289: on the edge of the image
# Cell 2 on image binary 299: on the edge of the image
# Cell 3 on image binary 300: on the edge of the image
# Cell 1 on image binary 301: on the edge of the image
# Cell 5 on image binary 302: on the edge of the image
# Cell 1 on image binary 306: on the edge of the image
# Cell 1 on image binary 308: on the edge of the image
# Image binary 313: No cells
# Image binary 314: No cells
# Cell 4 on image binary 325: on the edge of the image
# Cell 3 on image binary 328: on the edge of the image
# Image binary 333: No cells
# Image binary 334: No cells
# Cell 5 on image binary 337: on the edge of the image
# Image binary 341: No cells
# Image binary 344: No cells
# Cell 1 on image binary 347: on the edge of the image
# Cell 4 on image binary 354: on the edge of the image
# Cell 2 on image binary 356: on the edge of the image
# Image binary 359: No cells
# Image binary 364: No cells
# Image binary 365: No cells
# Image binary 367: No cells
# Image binary 372: No cells
# Cell 2 on image binary 380: on the edge of the image
# Cell 1 on image binary 388: on the edge of the image
# Cell 2 on image binary 388: on the edge of the image
# Image binary 394: No cells
# Image binary 402: No cells
# Image binary 405: No cells
# Image binary 407: No cells
# Image binary 408: No cells
# Cell 2 on image binary 411: on the edge of the image
# Image binary 413: No cells
# Cell 1 on image binary 417: on the edge of the image
# Image binary 420: No cells
# Image binary 425: No cells
# Cell 3 on image binary 426: on the edge of the image
# Image binary 438: No cells
# Image binary 447: No cells
# Cell 1 on image binary 468: on the edge of the image
# Image binary 470: No cells
# Image binary 477: No cells
# Image binary 478: No cells
# Image binary 479: No cells
# Image binary 482: No cells
# Cell 3 on image binary 484: on the edge of the image
# Image binary 486: No cells
# Image binary 487: No cells
# Image binary 490: No cells
# Image binary 493: No cells
# Image binary 496: No cells
# Image binary 499: No cells
# Image binary 500: No cells
# Cell 4 on image binary 504: on the edge of the image
# Cell 2 on image binary 508: on the edge of the image
# Cell 1 on image binary 520: on the edge of the image
# Image binary 522: No cells
# Image binary 524: No cells
# Image binary 527: No cells
# Cell 1 on image binary 529: on the edge of the image
# Image binary 531: No cells
# Image binary 537: No cells
# Cell 2 on image binary 552: on the edge of the image
# Image binary 560: No cells
# Image binary 561: No cells
# Cell 1 on image binary 562: on the edge of the image
# Image binary 564: No cells
# Image binary 570: No cells
# Image binary 571: No cells
# Image binary 572: No cells
# Image binary 573: No cells
# Image binary 574: No cells
# Image binary 575: No cells
# Image binary 578: No cells
# Image binary 580: No cells
# Image binary 581: No cells
# Image binary 582: No cells
# Image binary 583: No cells
# Image binary 584: No cells
# Image binary 588: No cells
# Image binary 590: No cells
# Image binary 591: No cells
# Image binary 592: No cells
# Image binary 598: No cells
# Image binary 599: No cells
# Image binary 611: No cells
# Image binary 612: No cells
# Cell 1 on image binary 615: on the edge of the image
# Image binary 617: No cells
# Cell 2 on image binary 620: on the edge of the image
# Image binary 621: No cells
# Image binary 622: No cells
# Image binary 623: No cells
# Image binary 630: No cells
# Cell 1 on image binary 632: on the edge of the image
# Image binary 633: No cells
# Image binary 639: No cells
# Cell 1 on image binary 644: on the edge of the image
# Image binary 646: No cells
# Cell 3 on image binary 648: on the edge of the image
# Image binary 652: No cells
# Image binary 659: No cells
# Image binary 660: No cells
# Cell 1 on image binary 664: on the edge of the image
# Image binary 665: No cells
# Image binary 666: No cells
# Image binary 669: No cells
# Image binary 672: No cells
# Cell 4 on image binary 679: on the edge of the image
# Image binary 680: No cells
# Image binary 685: No cells
# Image binary 689: No cells
# Image binary 691: No cells
# Image binary 692: No cells
# Image binary 696: No cells
# Image binary 697: No cells
# Image binary 698: No cells
# Image binary 699: No cells
# Image binary 702: No cells
# Image binary 707: No cells
# Image binary 708: No cells
# Image binary 709: No cells
# Image binary 711: No cells
# Image binary 714: No cells
# Image binary 718: No cells
# Image binary 720: No cells
# Image binary 730: No cells
# Image binary 735: No cells
# Image binary 736: No cells
# Image binary 737: No cells
# Image binary 739: No cells
# Image binary 740: No cells
# Image binary 742: No cells
# Cell 3 on image binary 748: on the edge of the image
# Image binary 749: No cells
# Image binary 750: No cells
# Cell 1 on image binary 755: on the edge of the image
# Image binary 761: No cells
# Image binary 768: No cells
# Cell 1 on image binary 769: on the edge of the image
# Cell 1 on image binary 772: on the edge of the image
# Cell 4 on image binary 774: on the edge of the image
# Cell 1 on image binary 777: on the edge of the image
# Image binary 778: No cells
# Image binary 779: No cells
# Image binary 787: No cells
# Image binary 788: No cells
# Image binary 799: No cells
# Image binary 801: No cells
# Image binary 802: No cells
# Image binary 803: No cells
# Image binary 806: No cells
# Image binary 807: No cells
# Image binary 808: No cells
# Image binary 810: No cells
# Image binary 812: No cells
# Image binary 813: No cells
# Image binary 814: No cells
# Image binary 815: No cells
# Image binary 820: No cells
# Cell 1 on image binary 821: on the edge of the image
# Image binary 823: No cells
# Image binary 828: No cells
# Image binary 833: No cells
# Image binary 837: No cells
# Image binary 840: No cells
# Image binary 842: No cells
# Image binary 854: No cells
# Cell 1 on image binary 855: on the edge of the image
# Image binary 857: No cells
# Image binary 858: No cells
# Image binary 860: No cells
# Image binary 861: No cells
# Image binary 863: No cells
# Image binary 869: No cells
# Image binary 871: No cells
# Image binary 872: No cells
# Image binary 873: No cells
# Image binary 874: No cells
# Image binary 875: No cells
# Cell 1 on image binary 880: on the edge of the image
# Image binary 881: No cells
# Image binary 882: No cells
# Image binary 883: No cells
# Image binary 884: No cells
# Image binary 886: No cells
# Image binary 888: No cells
# Image binary 889: No cells
# Image binary 891: No cells
# Image binary 898: No cells
# Cell 2 on image binary 900: on the edge of the image
# Image binary 904: No cells
# Image binary 908: No cells
# Image binary 909: No cells
# Image binary 911: No cells
# Cell 2 on image binary 912: on the edge of the image
# Image binary 914: No cells
# Image binary 916: No cells
# Image binary 918: No cells
# Image binary 919: No cells
# Image binary 920: No cells
# Image binary 925: No cells
# Image binary 926: No cells
# Image binary 928: No cells
# Image binary 932: No cells
# Image binary 934: No cells
# Image binary 935: No cells
# Image binary 941: No cells
# Image binary 942: No cells
# Image binary 945: No cells
# Image binary 946: No cells
# Image binary 953: No cells
# Image binary 956: No cells
# Image binary 961: No cells
# Image binary 962: No cells
# Image binary 964: No cells
# Image binary 968: No cells
# Image binary 970: No cells
# Image binary 973: No cells
# Image binary 974: No cells
# Image binary 978: No cells
# Image binary 979: No cells
# Image binary 980: No cells
# Image binary 982: No cells
# Image binary 983: No cells
# Image binary 984: No cells
# Image binary 987: No cells
# Image binary 988: No cells
# Image binary 989: No cells
# Image binary 990: No cells
# Image binary 991: No cells
# Image binary 993: No cells
# Image binary 996: No cells
# Image binary 997: No cells
# Image binary 998: No cells

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(c41_bf)
ax2.iter_imshow(c41_b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="736">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
len(cells)
# Out:
# 1386

# %%
aicp = AutoIterCellPlot(cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
save('c41_cell_raw.hdf5', cells)

# %%
epec_bf = np.load(os.path.join(input_dir, 'BF_EPEC_flat.npy'))
epec_bin = np.load(os.path.join(input_dir, 'epec_segmented.npy'))
epec_g100 = np.load(os.path.join(input_dir, 'epec_G100.npy'))
epec_g500 = np.load(os.path.join(input_dir, 'epec_G500.npy'))

# %%
epec_b_filter = filter_binaries(epec_bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(epec_b_filter, 'binary')
data.add_data(epec_bf, 'brightfield')
data.add_data(epec_g100, 'fluorescence', 'g100')
data.add_data(epec_g500, 'fluorescence', 'g500')

# %%
cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Image binary 10: No cells
# Cell 5 on image binary 11: on the edge of the image
# Cell 1 on image binary 12: on the edge of the image
# Cell 1 on image binary 13: on the edge of the image
# Cell 4 on image binary 19: on the edge of the image
# Cell 2 on image binary 27: on the edge of the image
# Cell 6 on image binary 28: on the edge of the image
# Cell 14 on image binary 32: on the edge of the image
# Cell 4 on image binary 38: on the edge of the image
# Cell 4 on image binary 41: on the edge of the image
# Cell 2 on image binary 60: on the edge of the image
# Cell 1 on image binary 63: on the edge of the image
# Cell 6 on image binary 67: on the edge of the image
# Cell 5 on image binary 68: on the edge of the image
# Cell 3 on image binary 69: on the edge of the image
# Cell 4 on image binary 75: on the edge of the image
# Cell 3 on image binary 78: on the edge of the image
# Cell 1 on image binary 79: on the edge of the image
# Cell 4 on image binary 79: on the edge of the image
# Cell 1 on image binary 84: on the edge of the image
# Cell 5 on image binary 87: on the edge of the image
# Image binary 89: No cells
# Image binary 92: No cells
# Cell 2 on image binary 97: on the edge of the image
# Cell 3 on image binary 101: on the edge of the image
# Cell 3 on image binary 111: on the edge of the image
# Cell 4 on image binary 111: on the edge of the image
# Cell 2 on image binary 112: on the edge of the image
# Image binary 113: No cells
# Cell 3 on image binary 121: on the edge of the image
# Cell 2 on image binary 124: on the edge of the image
# Cell 5 on image binary 125: on the edge of the image
# Image binary 132: No cells
# Cell 5 on image binary 144: on the edge of the image
# Cell 5 on image binary 145: on the edge of the image
# Cell 6 on image binary 146: on the edge of the image
# Cell 4 on image binary 149: on the edge of the image
# Cell 1 on image binary 150: on the edge of the image
# Cell 8 on image binary 151: on the edge of the image
# Cell 1 on image binary 156: on the edge of the image
# Cell 1 on image binary 157: on the edge of the image
# Cell 4 on image binary 157: on the edge of the image
# Cell 4 on image binary 161: on the edge of the image
# Image binary 162: No cells
# Cell 1 on image binary 171: on the edge of the image
# Image binary 180: No cells
# Image binary 181: No cells
# Cell 3 on image binary 182: on the edge of the image
# Image binary 183: No cells
# Cell 6 on image binary 192: on the edge of the image
# Cell 1 on image binary 194: on the edge of the image
# Image binary 195: No cells
# Cell 2 on image binary 216: on the edge of the image
# Cell 2 on image binary 223: on the edge of the image
# Cell 1 on image binary 229: on the edge of the image
# Image binary 250: No cells
# Image binary 254: No cells
# Image binary 256: No cells
# Cell 3 on image binary 267: on the edge of the image
# Image binary 269: No cells
# Cell 1 on image binary 272: on the edge of the image
# Image binary 280: No cells
# Image binary 283: No cells
# Cell 1 on image binary 289: on the edge of the image
# Image binary 294: No cells
# Cell 1 on image binary 295: on the edge of the image
# Image binary 296: No cells
# Image binary 302: No cells
# Image binary 303: No cells
# Image binary 306: No cells
# Image binary 309: No cells
# Image binary 313: No cells
# Cell 1 on image binary 329: on the edge of the image
# Image binary 333: No cells
# Cell 5 on image binary 343: on the edge of the image
# Image binary 347: No cells
# Cell 6 on image binary 349: on the edge of the image
# Image binary 350: No cells
# Cell 1 on image binary 362: on the edge of the image
# Cell 3 on image binary 363: on the edge of the image
# Image binary 374: No cells
# Cell 4 on image binary 375: on the edge of the image
# Image binary 376: No cells
# Cell 1 on image binary 377: on the edge of the image
# Image binary 378: No cells
# Cell 4 on image binary 385: on the edge of the image
# Image binary 389: No cells
# Cell 4 on image binary 394: on the edge of the image
# Image binary 395: No cells
# Cell 7 on image binary 405: on the edge of the image
# Image binary 411: No cells
# Cell 1 on image binary 413: on the edge of the image
# Cell 1 on image binary 417: on the edge of the image
# Image binary 421: No cells
# Cell 4 on image binary 422: on the edge of the image
# Cell 7 on image binary 428: on the edge of the image
# Image binary 432: No cells
# Image binary 439: No cells
# Image binary 441: No cells
# Cell 3 on image binary 445: on the edge of the image
# Cell 1 on image binary 448: on the edge of the image
# Cell 2 on image binary 453: on the edge of the image
# Image binary 461: No cells
# Image binary 462: No cells
# Cell 1 on image binary 474: on the edge of the image
# Cell 5 on image binary 487: on the edge of the image
# Cell 5 on image binary 493: on the edge of the image
# Cell 5 on image binary 494: on the edge of the image
# Cell 6 on image binary 497: on the edge of the image
# Cell 5 on image binary 508: on the edge of the image
# Cell 1 on image binary 510: on the edge of the image
# Cell 6 on image binary 514: on the edge of the image
# Image binary 519: No cells
# Image binary 525: No cells
# Cell 7 on image binary 530: on the edge of the image
# Image binary 532: No cells
# Cell 5 on image binary 547: on the edge of the image
# Cell 3 on image binary 548: on the edge of the image
# Image binary 551: No cells
# Cell 3 on image binary 554: on the edge of the image
# Image binary 557: No cells
# Cell 2 on image binary 558: on the edge of the image
# Cell 5 on image binary 563: on the edge of the image
# Cell 1 on image binary 567: on the edge of the image
# Cell 1 on image binary 568: on the edge of the image
# Cell 4 on image binary 569: on the edge of the image
# Cell 4 on image binary 576: on the edge of the image
# Image binary 593: No cells
# Cell 2 on image binary 598: on the edge of the image
# Cell 8 on image binary 600: on the edge of the image
# Cell 1 on image binary 607: on the edge of the image
# Cell 1 on image binary 610: on the edge of the image
# Cell 2 on image binary 611: on the edge of the image
# Cell 2 on image binary 612: on the edge of the image
# Cell 1 on image binary 619: on the edge of the image
# Cell 4 on image binary 621: on the edge of the image
# Image binary 625: No cells
# Cell 5 on image binary 642: on the edge of the image
# Image binary 647: No cells
# Cell 1 on image binary 659: on the edge of the image
# Cell 1 on image binary 664: on the edge of the image
# Cell 3 on image binary 671: on the edge of the image
# Cell 7 on image binary 675: on the edge of the image
# Cell 1 on image binary 677: on the edge of the image
# Cell 4 on image binary 678: on the edge of the image
# Cell 1 on image binary 679: on the edge of the image
# Image binary 689: No cells
# Cell 1 on image binary 690: on the edge of the image
# Cell 2 on image binary 690: on the edge of the image
# Cell 4 on image binary 693: on the edge of the image
# Cell 4 on image binary 695: on the edge of the image
# Cell 1 on image binary 697: on the edge of the image
# Image binary 718: No cells
# Image binary 724: No cells
# Cell 4 on image binary 727: on the edge of the image
# Cell 5 on image binary 728: on the edge of the image
# Image binary 734: No cells
# Image binary 735: No cells
# Cell 5 on image binary 740: on the edge of the image
# Cell 2 on image binary 743: on the edge of the image
# Cell 1 on image binary 744: on the edge of the image
# Cell 3 on image binary 744: on the edge of the image
# Cell 1 on image binary 745: on the edge of the image
# Cell 9 on image binary 751: on the edge of the image
# Cell 3 on image binary 754: on the edge of the image
# Cell 2 on image binary 760: on the edge of the image
# Cell 3 on image binary 767: on the edge of the image
# Cell 1 on image binary 770: on the edge of the image
# Cell 5 on image binary 772: on the edge of the image
# Image binary 773: No cells
# Image binary 782: No cells
# Cell 1 on image binary 786: on the edge of the image
# Cell 4 on image binary 790: on the edge of the image
# Cell 2 on image binary 793: on the edge of the image
# Cell 4 on image binary 803: on the edge of the image
# Image binary 807: No cells
# Cell 2 on image binary 808: on the edge of the image
# Cell 3 on image binary 819: on the edge of the image
# Image binary 823: No cells
# Image binary 828: No cells
# Image binary 829: No cells
# Image binary 831: No cells
# Cell 1 on image binary 839: on the edge of the image
# Cell 1 on image binary 845: on the edge of the image
# Cell 1 on image binary 849: on the edge of the image
# Cell 1 on image binary 850: on the edge of the image
# Cell 1 on image binary 855: on the edge of the image
# Cell 4 on image binary 861: on the edge of the image
# Cell 5 on image binary 867: on the edge of the image
# Cell 1 on image binary 873: on the edge of the image
# Cell 4 on image binary 875: on the edge of the image
# Cell 1 on image binary 876: on the edge of the image
# Cell 2 on image binary 881: on the edge of the image
# Cell 1 on image binary 884: on the edge of the image
# Cell 1 on image binary 893: on the edge of the image
# Cell 5 on image binary 895: on the edge of the image
# Cell 6 on image binary 901: on the edge of the image
# Image binary 902: No cells
# Cell 5 on image binary 904: on the edge of the image
# Cell 1 on image binary 907: on the edge of the image
# Cell 5 on image binary 912: on the edge of the image
# Image binary 922: No cells
# Cell 8 on image binary 929: on the edge of the image
# Image binary 934: No cells
# Cell 4 on image binary 950: on the edge of the image
# Image binary 952: No cells
# Image binary 953: No cells
# Cell 5 on image binary 955: on the edge of the image
# Image binary 957: No cells
# Image binary 965: No cells
# Cell 1 on image binary 984: on the edge of the image
# Cell 5 on image binary 984: on the edge of the image
# Cell 1 on image binary 986: on the edge of the image
# Image binary 993: No cells
# Cell 1 on image binary 995: on the edge of the image
# Cell 4 on image binary 999: on the edge of the image

# %%
len(cells)
# Out:
# 2536

# %%
save('epec_cell_raw.hdf5', cells)

# %%
aicp = AutoIterCellPlot(cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…
