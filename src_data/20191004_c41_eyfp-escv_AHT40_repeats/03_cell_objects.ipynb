# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from colicoords.preprocess import data_to_cells, filter_binaries
from colicoords import Data, iter_subplots, CellListPlot, IterCellPlot, AutoIterCellPlot, save
import os
import mahotas as mh

# %%
import colicoords
colicoords.__file__
# Out:
# 'C:\\Users\\jhs\\Programming\\cc_master\\colicoords\\__init__.py'

# %%
#input_dir = r'F:\_processed_big\t3ss\20191002_deltaescv_c41_eyfp-escv_repeat_03'
input_dir = r'H:\20191004_c41_eyfp-escv_AHT40_repeats'

# %%
c41_bf = np.load(os.path.join(input_dir, 'BF_C41_02_flat.npy'))
c41_bin = np.load(os.path.join(input_dir, 'c41_02_segmented.npy'))
c41_g100 = np.load(os.path.join(input_dir, 'c41_repeat_02_514_g100.npy'))
c41_g500 = np.load(os.path.join(input_dir, 'c41_repeat_02_514_g500.npy'))

# %%
c41_g500.shape
# Out:
# (1200, 512, 512)

# %%
c41_b_filter = filter_binaries(c41_bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(c41_b_filter, 'binary')
data.add_data(c41_bf, 'brightfield')
data.add_data(c41_g100, 'fluorescence', 'g100')
data.add_data(c41_g500, 'fluorescence', 'g500')

# %%
cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Cell 2 on image binary 1: on the edge of the image
# Cell 6 on image binary 4: on the edge of the image
# Cell 6 on image binary 7: on the edge of the image
# Cell 10 on image binary 15: on the edge of the image
# Cell 1 on image binary 18: on the edge of the image
# Cell 2 on image binary 18: on the edge of the image
# Cell 11 on image binary 19: on the edge of the image
# Cell 9 on image binary 22: on the edge of the image
# Cell 4 on image binary 26: on the edge of the image
# Cell 5 on image binary 27: on the edge of the image
# Cell 6 on image binary 29: on the edge of the image
# Cell 16 on image binary 30: on the edge of the image
# Cell 1 on image binary 31: on the edge of the image
# Cell 13 on image binary 32: on the edge of the image
# Cell 14 on image binary 35: on the edge of the image
# Cell 25 on image binary 36: on the edge of the image
# Cell 6 on image binary 38: on the edge of the image
# Cell 2 on image binary 41: on the edge of the image
# ...

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(c41_bf)
ax2.iter_imshow(c41_b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
len(cells)
# Out:
# 7939

# %%
aicp = AutoIterCellPlot(cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# ...

# %%
save('c41_02_cell_raw.hdf5', cells)

# %%
c41_03_bf = np.load(os.path.join(input_dir, 'BF_C41_03_flat.npy'))
c41_03_bin = np.load(os.path.join(input_dir, 'c41_03_segmented.npy'))
c41_03_g100 = np.load(os.path.join(input_dir, 'c41_repeat_03_514_g100.npy'))
c41_03_g500 = np.load(os.path.join(input_dir, 'c41_repeat_03_514_g500.npy'))

# %%
c41_03_b_filter = filter_binaries(c41_03_bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(c41_03_b_filter, 'binary')
data.add_data(c41_03_bf, 'brightfield')
data.add_data(c41_03_g100, 'fluorescence', 'g100')
data.add_data(c41_03_g500, 'fluorescence', 'g500')

# %%
cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Cell 1 on image binary 3: on the edge of the image
# Cell 2 on image binary 4: on the edge of the image
# Image binary 8: No cells
# Image binary 22: No cells
# Cell 1 on image binary 24: on the edge of the image
# Cell 1 on image binary 29: on the edge of the image
# Image binary 41: No cells
# Image binary 42: No cells
# Cell 13 on image binary 47: on the edge of the image
# Image binary 51: No cells
# Image binary 53: No cells
# Image binary 58: No cells
# Cell 3 on image binary 59: on the edge of the image
# Image binary 60: No cells
# Image binary 61: No cells
# Image binary 62: No cells
# Image binary 63: No cells
# Image binary 64: No cells
# Image binary 71: No cells
# Image binary 74: No cells
# Cell 1 on image binary 83: on the edge of the image
# Image binary 87: No cells
# Cell 1 on image binary 89: on the edge of the image
# Cell 5 on image binary 93: on the edge of the image
# Cell 3 on image binary 108: on the edge of the image
# Image binary 111: No cells
# ...

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(c41_03_bf)
ax2.iter_imshow(c41_03_b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
len(cells)
# Out:
# 4043

# %%
aicp = AutoIterCellPlot(cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# ...

# %%
save('c41_03_cell_raw.hdf5', cells)
