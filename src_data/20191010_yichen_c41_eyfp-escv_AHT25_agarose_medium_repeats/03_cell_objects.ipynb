# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from colicoords.preprocess import data_to_cells, filter_binaries
from colicoords import Data, iter_subplots, CellListPlot, IterCellPlot, AutoIterCellPlot, save
import os
import mahotas as mh
from addict import Dict

# %%
import colicoords
colicoords.__file__
# Out:
# 'C:\\Users\\jhs\\Programming\\cc_master\\colicoords\\__init__.py'

# %%
#input_dir = r'F:\_processed_big\t3ss\20191002_deltaescv_c41_eyfp-escv_repeat_03'
input_dir = r'E:\20191010_c41_eyfp-escv_AHT25_agarose_medium_repeats'

# %% [markdown]
# # C41 01

# %%
dd = Dict()
f = 'c41_01'

# %%
dd.bf = np.load(os.path.join(input_dir, f + '_BF_flat.npy'))
dd.bin = np.load(os.path.join(input_dir, f + '_segmented.npy'))
dd.g100 = np.load(os.path.join(input_dir, f + '_514_g100.npy'))
dd.g500 = np.load(os.path.join(input_dir, f + '_514_g500.npy'))

# %%
dd.bf.shape
# Out:
# (1200, 512, 512)

# %%
dd.b_filter = filter_binaries(dd.bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(dd.b_filter, 'binary')
data.add_data(dd.bf, 'brightfield')
data.add_data(dd.g100, 'fluorescence', 'g100')
data.add_data(dd.g500, 'fluorescence', 'g500')

# %%
dd.cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Image binary 9: No cells
# Cell 1 on image binary 10: on the edge of the image
# 16 2
# Image binary 19: No cells
# Image binary 34: No cells
# Cell 9 on image binary 40: on the edge of the image
# Cell 1 on image binary 41: on the edge of the image
# Cell 2 on image binary 43: on the edge of the image
# Image binary 47: No cells
# Cell 9 on image binary 51: on the edge of the image
# Image binary 57: No cells
# Image binary 58: No cells
# Cell 1 on image binary 60: on the edge of the image
# Image binary 61: No cells
# Image binary 67: No cells
# Image binary 69: No cells
# Cell 1 on image binary 72: on the edge of the image
# Image binary 78: No cells
# Image binary 79: No cells
# Cell 3 on image binary 80: on the edge of the image
# Image binary 84: No cells
# Image binary 93: No cells
# Image binary 97: No cells
# Image binary 98: No cells
# Cell 2 on image binary 100: on the edge of the image
# Cell 6 on image binary 108: on the edge of the image
# Image binary 110: No cells
# Image binary 120: No cells
# Cell 4 on image binary 127: on the edge of the image
# Image binary 130: No cells
# Image binary 133: No cells
# Image binary 141: No cells
# Cell 5 on image binary 147: on the edge of the image
# Image binary 150: No cells
# Image binary 151: No cells
# Image binary 153: No cells
# Cell 1 on image binary 156: on the edge of the image
# Image binary 160: No cells
# Image binary 170: No cells
# Image binary 171: No cells
# Image binary 173: No cells
# Image binary 174: No cells
# Cell 3 on image binary 177: on the edge of the image
# Image binary 183: No cells
# Image binary 184: No cells
# Image binary 187: No cells
# Image binary 189: No cells
# Image binary 190: No cells
# Cell 2 on image binary 194: on the edge of the image
# Cell 3 on image binary 195: on the edge of the image
# Image binary 196: No cells
# Image binary 197: No cells
# Cell 5 on image binary 204: on the edge of the image
# Cell 5 on image binary 210: on the edge of the image
# Cell 3 on image binary 216: on the edge of the image
# Image binary 229: No cells
# Image binary 230: No cells
# Cell 5 on image binary 232: on the edge of the image
# Cell 6 on image binary 236: on the edge of the image
# Cell 9 on image binary 237: on the edge of the image
# Cell 7 on image binary 240: on the edge of the image
# Cell 3 on image binary 242: on the edge of the image
# Cell 7 on image binary 246: on the edge of the image
# Cell 4 on image binary 251: on the edge of the image
# Cell 4 on image binary 252: on the edge of the image
# Cell 1 on image binary 253: on the edge of the image
# Cell 1 on image binary 255: on the edge of the image
# Cell 8 on image binary 257: on the edge of the image
# Image binary 260: No cells
# Cell 6 on image binary 269: on the edge of the image
# Cell 2 on image binary 273: on the edge of the image
# Cell 1 on image binary 274: on the edge of the image
# Cell 11 on image binary 275: on the edge of the image
# Cell 5 on image binary 279: on the edge of the image
# Cell 1 on image binary 280: on the edge of the image
# Cell 1 on image binary 281: on the edge of the image
# Cell 2 on image binary 286: on the edge of the image
# Cell 2 on image binary 295: on the edge of the image
# Cell 6 on image binary 299: on the edge of the image
# Cell 2 on image binary 301: on the edge of the image
# Cell 2 on image binary 305: on the edge of the image
# Image binary 307: No cells
# Cell 1 on image binary 316: on the edge of the image
# Cell 1 on image binary 319: on the edge of the image
# Image binary 323: No cells
# Cell 1 on image binary 324: on the edge of the image
# Cell 10 on image binary 338: on the edge of the image
# Cell 1 on image binary 341: on the edge of the image
# Cell 1 on image binary 343: on the edge of the image
# Cell 4 on image binary 344: on the edge of the image
# Cell 2 on image binary 351: on the edge of the image
# Cell 3 on image binary 352: on the edge of the image
# Cell 4 on image binary 352: on the edge of the image
# Cell 1 on image binary 355: on the edge of the image
# Image binary 360: No cells
# Image binary 365: No cells
# Cell 1 on image binary 373: on the edge of the image
# Cell 4 on image binary 373: on the edge of the image
# Cell 1 on image binary 383: on the edge of the image
# Image binary 390: No cells
# Image binary 393: No cells
# Cell 4 on image binary 394: on the edge of the image
# Cell 1 on image binary 395: on the edge of the image
# Cell 7 on image binary 400: on the edge of the image
# Cell 1 on image binary 404: on the edge of the image
# Image binary 407: No cells
# Image binary 410: No cells
# Image binary 413: No cells
# Image binary 414: No cells
# Image binary 419: No cells
# Cell 1 on image binary 422: on the edge of the image
# Image binary 427: No cells
# Image binary 436: No cells
# Image binary 438: No cells
# Image binary 440: No cells
# Image binary 442: No cells
# Image binary 447: No cells
# Image binary 449: No cells
# Image binary 455: No cells
# Image binary 458: No cells
# Cell 1 on image binary 459: on the edge of the image
# Image binary 460: No cells
# Cell 2 on image binary 462: on the edge of the image
# Image binary 463: No cells
# Image binary 464: No cells
# Image binary 466: No cells
# Image binary 467: No cells
# Image binary 472: No cells
# Image binary 475: No cells
# Image binary 479: No cells
# Image binary 480: No cells
# Cell 2 on image binary 481: on the edge of the image
# Image binary 484: No cells
# Image binary 485: No cells
# Image binary 486: No cells
# Image binary 488: No cells
# Image binary 489: No cells
# Image binary 492: No cells
# Image binary 494: No cells
# Image binary 498: No cells
# Image binary 499: No cells
# Image binary 506: No cells
# Image binary 512: No cells
# Image binary 514: No cells
# Image binary 516: No cells
# Image binary 520: No cells
# Image binary 523: No cells
# Image binary 526: No cells
# Image binary 530: No cells
# Image binary 534: No cells
# Image binary 537: No cells
# Image binary 541: No cells
# Image binary 550: No cells
# Image binary 552: No cells
# Image binary 554: No cells
# Image binary 559: No cells
# Image binary 560: No cells
# Image binary 561: No cells
# Image binary 562: No cells
# Image binary 564: No cells
# Image binary 568: No cells
# Image binary 570: No cells
# Image binary 572: No cells
# Image binary 573: No cells
# Image binary 574: No cells
# Image binary 575: No cells
# Image binary 578: No cells
# Image binary 580: No cells
# Image binary 582: No cells
# Image binary 584: No cells
# Image binary 585: No cells
# Image binary 586: No cells
# Image binary 590: No cells
# Image binary 592: No cells
# Image binary 594: No cells
# Image binary 595: No cells
# Image binary 598: No cells
# Image binary 599: No cells
# Cell 10 on image binary 622: on the edge of the image
# Cell 6 on image binary 629: on the edge of the image
# Cell 8 on image binary 632: on the edge of the image
# Cell 5 on image binary 635: on the edge of the image
# Cell 5 on image binary 636: on the edge of the image
# Cell 5 on image binary 640: on the edge of the image
# Cell 1 on image binary 643: on the edge of the image
# Cell 1 on image binary 644: on the edge of the image
# Cell 1 on image binary 650: on the edge of the image
# Cell 4 on image binary 652: on the edge of the image
# Cell 3 on image binary 653: on the edge of the image
# Cell 8 on image binary 661: on the edge of the image
# Cell 1 on image binary 671: on the edge of the image
# Cell 6 on image binary 678: on the edge of the image
# Cell 4 on image binary 684: on the edge of the image
# Cell 3 on image binary 691: on the edge of the image
# Image binary 693: No cells
# Cell 1 on image binary 703: on the edge of the image
# Cell 2 on image binary 714: on the edge of the image
# Cell 5 on image binary 714: on the edge of the image
# Cell 7 on image binary 715: on the edge of the image
# Cell 5 on image binary 721: on the edge of the image
# Cell 5 on image binary 722: on the edge of the image
# Cell 2 on image binary 724: on the edge of the image
# Cell 3 on image binary 727: on the edge of the image
# Cell 5 on image binary 728: on the edge of the image
# Cell 1 on image binary 732: on the edge of the image
# Cell 2 on image binary 734: on the edge of the image
# Cell 1 on image binary 735: on the edge of the image
# Cell 9 on image binary 745: on the edge of the image
# Cell 6 on image binary 746: on the edge of the image
# Cell 7 on image binary 747: on the edge of the image
# Cell 2 on image binary 750: on the edge of the image
# Cell 3 on image binary 763: on the edge of the image
# Cell 8 on image binary 768: on the edge of the image
# Cell 3 on image binary 771: on the edge of the image
# Cell 4 on image binary 773: on the edge of the image
# Image binary 774: No cells
# Cell 3 on image binary 778: on the edge of the image
# Cell 4 on image binary 779: on the edge of the image
# Image binary 780: No cells
# Cell 7 on image binary 784: on the edge of the image
# Cell 1 on image binary 786: on the edge of the image
# Image binary 797: No cells
# Cell 1 on image binary 810: on the edge of the image
# Cell 2 on image binary 812: on the edge of the image
# Image binary 818: No cells
# Image binary 820: No cells
# Image binary 832: No cells
# Image binary 836: No cells
# Cell 3 on image binary 842: on the edge of the image
# Image binary 853: No cells
# Image binary 856: No cells
# Image binary 858: No cells
# Image binary 862: No cells
# Image binary 863: No cells
# Image binary 867: No cells
# Image binary 871: No cells
# Image binary 872: No cells
# Image binary 875: No cells
# Image binary 877: No cells
# Cell 3 on image binary 878: on the edge of the image
# Image binary 881: No cells
# Image binary 883: No cells
# Image binary 885: No cells
# Image binary 886: No cells
# Image binary 890: No cells
# Image binary 891: No cells
# Cell 1 on image binary 892: on the edge of the image
# Image binary 896: No cells
# Image binary 897: No cells
# Image binary 903: No cells
# Image binary 906: No cells
# Cell 4 on image binary 909: on the edge of the image
# Cell 3 on image binary 921: on the edge of the image
# Cell 1 on image binary 922: on the edge of the image
# Cell 3 on image binary 923: on the edge of the image
# Image binary 927: No cells
# Image binary 929: No cells
# Image binary 930: No cells
# Cell 6 on image binary 931: on the edge of the image
# Cell 1 on image binary 939: on the edge of the image
# Image binary 940: No cells
# Image binary 942: No cells
# Cell 1 on image binary 945: on the edge of the image
# Image binary 947: No cells
# Image binary 950: No cells
# Cell 1 on image binary 956: on the edge of the image
# Image binary 961: No cells
# Image binary 964: No cells
# Image binary 970: No cells
# Image binary 971: No cells
# Image binary 974: No cells
# Image binary 975: No cells
# Image binary 979: No cells
# Image binary 980: No cells
# Image binary 985: No cells
# Image binary 986: No cells
# Image binary 990: No cells
# Image binary 994: No cells
# Image binary 996: No cells
# Cell 10 on image binary 1000: on the edge of the image
# Cell 4 on image binary 1017: on the edge of the image
# Cell 8 on image binary 1019: on the edge of the image
# Cell 3 on image binary 1020: on the edge of the image
# Cell 1 on image binary 1023: on the edge of the image
# Cell 5 on image binary 1027: on the edge of the image
# Cell 3 on image binary 1034: on the edge of the image
# Cell 3 on image binary 1037: on the edge of the image
# Cell 7 on image binary 1041: on the edge of the image
# Cell 2 on image binary 1050: on the edge of the image
# Cell 2 on image binary 1052: on the edge of the image
# Cell 1 on image binary 1057: on the edge of the image
# Cell 1 on image binary 1059: on the edge of the image
# Cell 7 on image binary 1060: on the edge of the image
# Cell 7 on image binary 1061: on the edge of the image
# Cell 9 on image binary 1068: on the edge of the image
# Image binary 1069: No cells
# Cell 1 on image binary 1071: on the edge of the image
# Cell 8 on image binary 1073: on the edge of the image
# Cell 2 on image binary 1080: on the edge of the image
# 1087 3
# Image binary 1089: No cells
# Cell 5 on image binary 1092: on the edge of the image
# Cell 1 on image binary 1095: on the edge of the image
# Image binary 1097: No cells
# Image binary 1112: No cells
# Cell 5 on image binary 1115: on the edge of the image
# Image binary 1124: No cells
# Cell 1 on image binary 1130: on the edge of the image
# Cell 2 on image binary 1138: on the edge of the image
# Cell 3 on image binary 1140: on the edge of the image
# Cell 3 on image binary 1147: on the edge of the image
# Cell 7 on image binary 1148: on the edge of the image
# Cell 1 on image binary 1157: on the edge of the image
# Cell 1 on image binary 1162: on the edge of the image
# Cell 5 on image binary 1162: on the edge of the image
# Cell 1 on image binary 1164: on the edge of the image
# Cell 3 on image binary 1176: on the edge of the image
# Cell 6 on image binary 1179: on the edge of the image
# Cell 1 on image binary 1190: on the edge of the image
# Cell 4 on image binary 1190: on the edge of the image
# Image binary 1192: No cells

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(dd.bf)
ax2.iter_imshow(dd.b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
len(dd.cells)
# Out:
# 3261

# %%
aicp = AutoIterCellPlot(dd.cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
save(f + '_cell_raw.hdf5', dd.cells)

# %% [markdown]
# # c41 02

# %%
dd = Dict()
f = 'c41_02'

# %%
dd.bf = np.load(os.path.join(input_dir, f + '_BF_flat.npy'))
dd.bin = np.load(os.path.join(input_dir, f + '_segmented.npy'))
dd.g100 = np.load(os.path.join(input_dir, f + '_514_g100.npy'))
dd.g500 = np.load(os.path.join(input_dir, f + '_514_g500.npy'))

# %%
dd.bf.shape
# Out:
# (1200, 512, 512)

# %%
dd.b_filter = filter_binaries(dd.bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(dd.b_filter, 'binary')
data.add_data(dd.bf, 'brightfield')
data.add_data(dd.g100, 'fluorescence', 'g100')
data.add_data(dd.g500, 'fluorescence', 'g500')

# %%
dd.cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Cell 8 on image binary 0: on the edge of the image
# Cell 2 on image binary 4: on the edge of the image
# Cell 4 on image binary 7: on the edge of the image
# Image binary 15: No cells
# Cell 1 on image binary 22: on the edge of the image
# Cell 5 on image binary 25: on the edge of the image
# Image binary 30: No cells
# Cell 5 on image binary 31: on the edge of the image
# Cell 1 on image binary 34: on the edge of the image
# Image binary 40: No cells
# Image binary 42: No cells
# Cell 4 on image binary 56: on the edge of the image
# Cell 1 on image binary 67: on the edge of the image
# Cell 1 on image binary 70: on the edge of the image
# Cell 3 on image binary 71: on the edge of the image
# Cell 2 on image binary 72: on the edge of the image
# Image binary 76: No cells
# Cell 2 on image binary 82: on the edge of the image
# Cell 4 on image binary 85: on the edge of the image
# Cell 8 on image binary 91: on the edge of the image
# Cell 2 on image binary 94: on the edge of the image
# Cell 6 on image binary 96: on the edge of the image
# Cell 1 on image binary 102: on the edge of the image
# Image binary 107: No cells
# Cell 7 on image binary 112: on the edge of the image
# Cell 2 on image binary 118: on the edge of the image
# Cell 1 on image binary 119: on the edge of the image
# Cell 1 on image binary 120: on the edge of the image
# Cell 4 on image binary 125: on the edge of the image
# Cell 4 on image binary 134: on the edge of the image
# Cell 1 on image binary 140: on the edge of the image
# Cell 1 on image binary 145: on the edge of the image
# Image binary 149: No cells
# Cell 1 on image binary 157: on the edge of the image
# Image binary 160: No cells
# Cell 2 on image binary 165: on the edge of the image
# Image binary 180: No cells
# Cell 1 on image binary 188: on the edge of the image
# Image binary 201: No cells
# Cell 1 on image binary 204: on the edge of the image
# Image binary 210: No cells
# Image binary 220: No cells
# Image binary 222: No cells
# Cell 1 on image binary 224: on the edge of the image
# Cell 3 on image binary 230: on the edge of the image
# Cell 1 on image binary 246: on the edge of the image
# Cell 1 on image binary 251: on the edge of the image
# Cell 1 on image binary 258: on the edge of the image
# Cell 1 on image binary 286: on the edge of the image
# Cell 1 on image binary 289: on the edge of the image
# Image binary 290: No cells
# Cell 1 on image binary 301: on the edge of the image
# Cell 1 on image binary 309: on the edge of the image
# Cell 2 on image binary 315: on the edge of the image
# Cell 8 on image binary 321: on the edge of the image
# Cell 6 on image binary 334: on the edge of the image
# Image binary 336: No cells
# Cell 1 on image binary 348: on the edge of the image
# Cell 5 on image binary 348: on the edge of the image
# Cell 1 on image binary 367: on the edge of the image
# Cell 1 on image binary 368: on the edge of the image
# Image binary 374: No cells
# Cell 1 on image binary 383: on the edge of the image
# Cell 2 on image binary 387: on the edge of the image
# Image binary 389: No cells
# Cell 4 on image binary 391: on the edge of the image
# Image binary 394: No cells
# Cell 1 on image binary 398: on the edge of the image
# Cell 7 on image binary 398: on the edge of the image
# Cell 8 on image binary 398: on the edge of the image
# Image binary 403: No cells
# Image binary 404: No cells
# Image binary 406: No cells
# Image binary 409: No cells
# Image binary 410: No cells
# Cell 1 on image binary 412: on the edge of the image
# Image binary 417: No cells
# Image binary 419: No cells
# Image binary 420: No cells
# Image binary 423: No cells
# Image binary 427: No cells
# Image binary 438: No cells
# Image binary 441: No cells
# Image binary 448: No cells
# Image binary 452: No cells
# Image binary 456: No cells
# Image binary 457: No cells
# Image binary 463: No cells
# Cell 2 on image binary 464: on the edge of the image
# Image binary 469: No cells
# Image binary 470: No cells
# Image binary 473: No cells
# Cell 1 on image binary 481: on the edge of the image
# Cell 3 on image binary 481: on the edge of the image
# Image binary 484: No cells
# Image binary 495: No cells
# Image binary 501: No cells
# Image binary 502: No cells
# Cell 4 on image binary 504: on the edge of the image
# Cell 1 on image binary 508: on the edge of the image
# Image binary 510: No cells
# Image binary 511: No cells
# Image binary 514: No cells
# Image binary 516: No cells
# Image binary 520: No cells
# Image binary 522: No cells
# Cell 1 on image binary 525: on the edge of the image
# Image binary 526: No cells
# Image binary 529: No cells
# Image binary 532: No cells
# Cell 2 on image binary 535: on the edge of the image
# Cell 1 on image binary 537: on the edge of the image
# Image binary 538: No cells
# Image binary 542: No cells
# Image binary 543: No cells
# Cell 1 on image binary 549: on the edge of the image
# Cell 1 on image binary 550: on the edge of the image
# Image binary 551: No cells
# Cell 2 on image binary 552: on the edge of the image
# Cell 3 on image binary 555: on the edge of the image
# Image binary 561: No cells
# Cell 1 on image binary 566: on the edge of the image
# Image binary 570: No cells
# Image binary 571: No cells
# Image binary 580: No cells
# Cell 4 on image binary 581: on the edge of the image
# Image binary 583: No cells
# Image binary 591: No cells
# Image binary 601: No cells
# Cell 2 on image binary 603: on the edge of the image
# Image binary 610: No cells
# Image binary 624: No cells
# Image binary 625: No cells
# Cell 1 on image binary 626: on the edge of the image
# Image binary 630: No cells
# Cell 5 on image binary 637: on the edge of the image
# Cell 4 on image binary 638: on the edge of the image
# Cell 1 on image binary 647: on the edge of the image
# Cell 5 on image binary 651: on the edge of the image
# Image binary 658: No cells
# Image binary 664: No cells
# Cell 4 on image binary 665: on the edge of the image
# Image binary 673: No cells
# Cell 2 on image binary 676: on the edge of the image
# Image binary 687: No cells
# Image binary 690: No cells
# Cell 1 on image binary 692: on the edge of the image
# Cell 3 on image binary 695: on the edge of the image
# Image binary 696: No cells
# Cell 4 on image binary 698: on the edge of the image
# Cell 1 on image binary 708: on the edge of the image
# Cell 3 on image binary 718: on the edge of the image
# Cell 2 on image binary 725: on the edge of the image
# Image binary 726: No cells
# Cell 1 on image binary 727: on the edge of the image
# Image binary 730: No cells
# Cell 1 on image binary 732: on the edge of the image
# Cell 4 on image binary 732: on the edge of the image
# Image binary 740: No cells
# Image binary 743: No cells
# Cell 3 on image binary 747: on the edge of the image
# Image binary 756: No cells
# Image binary 760: No cells
# Image binary 765: No cells
# Image binary 767: No cells
# Image binary 770: No cells
# Image binary 771: No cells
# Image binary 773: No cells
# Image binary 774: No cells
# Image binary 780: No cells
# Image binary 782: No cells
# Image binary 790: No cells
# Image binary 791: No cells
# Image binary 792: No cells
# Image binary 793: No cells
# Image binary 794: No cells
# Cell 1 on image binary 814: on the edge of the image
# Image binary 818: No cells
# Image binary 820: No cells
# Image binary 822: No cells
# Image binary 823: No cells
# Cell 1 on image binary 827: on the edge of the image
# Image binary 832: No cells
# Image binary 835: No cells
# Image binary 836: No cells
# Image binary 837: No cells
# Cell 6 on image binary 839: on the edge of the image
# Image binary 848: No cells
# Image binary 849: No cells
# Cell 1 on image binary 851: on the edge of the image
# Cell 5 on image binary 863: on the edge of the image
# Image binary 864: No cells
# Image binary 874: No cells
# Cell 6 on image binary 881: on the edge of the image
# Cell 3 on image binary 885: on the edge of the image
# Image binary 890: No cells
# Image binary 891: No cells
# Cell 1 on image binary 893: on the edge of the image
# Cell 4 on image binary 895: on the edge of the image
# Cell 6 on image binary 897: on the edge of the image
# Image binary 902: No cells
# Cell 3 on image binary 903: on the edge of the image
# Cell 3 on image binary 907: on the edge of the image
# Cell 1 on image binary 910: on the edge of the image
# Cell 4 on image binary 910: on the edge of the image
# Cell 3 on image binary 912: on the edge of the image
# Cell 4 on image binary 912: on the edge of the image
# Image binary 914: No cells
# Image binary 923: No cells
# Image binary 932: No cells
# Image binary 934: No cells
# Image binary 937: No cells
# Cell 3 on image binary 938: on the edge of the image
# Image binary 943: No cells
# Image binary 944: No cells
# Image binary 945: No cells
# Image binary 950: No cells
# Cell 2 on image binary 951: on the edge of the image
# Image binary 952: No cells
# Image binary 953: No cells
# Image binary 957: No cells
# Cell 1 on image binary 961: on the edge of the image
# Image binary 963: No cells
# Image binary 970: No cells
# Cell 3 on image binary 972: on the edge of the image
# Cell 1 on image binary 974: on the edge of the image
# Image binary 976: No cells
# Cell 1 on image binary 977: on the edge of the image
# Cell 4 on image binary 979: on the edge of the image
# Cell 8 on image binary 983: on the edge of the image
# Cell 6 on image binary 994: on the edge of the image
# Cell 2 on image binary 995: on the edge of the image
# Cell 3 on image binary 998: on the edge of the image
# Image binary 1021: No cells
# Cell 1 on image binary 1023: on the edge of the image
# Image binary 1030: No cells
# Cell 4 on image binary 1033: on the edge of the image
# Image binary 1038: No cells
# Image binary 1040: No cells
# Image binary 1044: No cells
# Cell 1 on image binary 1047: on the edge of the image
# Image binary 1052: No cells
# Image binary 1054: No cells
# Image binary 1059: No cells
# Image binary 1067: No cells
# Cell 2 on image binary 1082: on the edge of the image
# Cell 4 on image binary 1085: on the edge of the image
# Cell 6 on image binary 1085: on the edge of the image
# Image binary 1089: No cells
# Cell 1 on image binary 1097: on the edge of the image
# Cell 3 on image binary 1098: on the edge of the image
# Image binary 1100: No cells
# Cell 6 on image binary 1105: on the edge of the image
# Image binary 1109: No cells
# Image binary 1110: No cells
# Cell 1 on image binary 1111: on the edge of the image
# Image binary 1118: No cells
# Image binary 1124: No cells
# Cell 1 on image binary 1127: on the edge of the image
# Image binary 1131: No cells
# Image binary 1136: No cells
# Image binary 1144: No cells
# Image binary 1150: No cells
# Image binary 1152: No cells
# Image binary 1155: No cells
# Cell 1 on image binary 1159: on the edge of the image
# Image binary 1160: No cells
# Cell 4 on image binary 1164: on the edge of the image
# Image binary 1169: No cells
# Image binary 1170: No cells
# Image binary 1172: No cells
# Image binary 1173: No cells
# Image binary 1177: No cells
# Image binary 1178: No cells
# Image binary 1180: No cells
# Cell 4 on image binary 1189: on the edge of the image
# Cell 1 on image binary 1191: on the edge of the image

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(dd.bf)
ax2.iter_imshow(dd.b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
len(dd.cells)
# Out:
# 2693

# %%
aicp = AutoIterCellPlot(dd.cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
save(f + '_cell_raw.hdf5', dd.cells)

# %% [markdown]
# # C41 03

# %%
dd = Dict()
f = 'c41_03'

# %%
dd.bf = np.load(os.path.join(input_dir, f + '_BF_flat.npy'))
dd.bin = np.load(os.path.join(input_dir, f + '_segmented.npy'))
dd.g100 = np.load(os.path.join(input_dir, f + '_514_g100.npy'))
dd.g500 = np.load(os.path.join(input_dir, f + '_514_g500.npy'))

# %%
dd.bf.shape
# Out:
# (1000, 512, 512)

# %%
dd.b_filter = filter_binaries(dd.bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(dd.b_filter, 'binary')
data.add_data(dd.bf, 'brightfield')
data.add_data(dd.g100, 'fluorescence', 'g100')
data.add_data(dd.g500, 'fluorescence', 'g500')

# %%
dd.cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Image binary 9: No cells
# Image binary 19: No cells
# 32 1
# Image binary 44: No cells
# Image binary 54: No cells
# Cell 1 on image binary 61: on the edge of the image
# Image binary 69: No cells
# Image binary 70: No cells
# Image binary 71: No cells
# Cell 2 on image binary 75: on the edge of the image
# Image binary 79: No cells
# Cell 1 on image binary 90: on the edge of the image
# Cell 7 on image binary 98: on the edge of the image
# Cell 4 on image binary 103: on the edge of the image
# Image binary 122: No cells
# Cell 4 on image binary 125: on the edge of the image
# Image binary 132: No cells
# Image binary 139: No cells
# Image binary 145: No cells
# Cell 2 on image binary 148: on the edge of the image
# Cell 5 on image binary 148: on the edge of the image
# Cell 4 on image binary 156: on the edge of the image
# Cell 4 on image binary 158: on the edge of the image
# Cell 7 on image binary 159: on the edge of the image
# Image binary 163: No cells
# Cell 1 on image binary 164: on the edge of the image
# Cell 1 on image binary 167: on the edge of the image
# Image binary 170: No cells
# Cell 2 on image binary 182: on the edge of the image
# Cell 2 on image binary 184: on the edge of the image
# Cell 1 on image binary 189: on the edge of the image
# Cell 3 on image binary 190: on the edge of the image
# Cell 1 on image binary 194: on the edge of the image
# Image binary 205: No cells
# Cell 4 on image binary 210: on the edge of the image
# Image binary 250: No cells
# Image binary 264: No cells
# Image binary 274: No cells
# Image binary 288: No cells
# Image binary 292: No cells
# Cell 1 on image binary 294: on the edge of the image
# Image binary 297: No cells
# Image binary 299: No cells
# Cell 1 on image binary 303: on the edge of the image
# Image binary 318: No cells
# Cell 2 on image binary 322: on the edge of the image
# Cell 4 on image binary 325: on the edge of the image
# Cell 1 on image binary 327: on the edge of the image
# Image binary 329: No cells
# Cell 1 on image binary 334: on the edge of the image
# Cell 4 on image binary 336: on the edge of the image
# Cell 1 on image binary 338: on the edge of the image
# Cell 9 on image binary 339: on the edge of the image
# Image binary 340: No cells
# Image binary 341: No cells
# Image binary 344: No cells
# Cell 3 on image binary 346: on the edge of the image
# Cell 2 on image binary 351: on the edge of the image
# Image binary 353: No cells
# Image binary 360: No cells
# Image binary 363: No cells
# Image binary 365: No cells
# Image binary 367: No cells
# Image binary 373: No cells
# Cell 3 on image binary 379: on the edge of the image
# Cell 4 on image binary 379: on the edge of the image
# Image binary 384: No cells
# Image binary 386: No cells
# Cell 3 on image binary 388: on the edge of the image
# Image binary 395: No cells
# Cell 3 on image binary 402: on the edge of the image
# Cell 2 on image binary 404: on the edge of the image
# Cell 2 on image binary 419: on the edge of the image
# Cell 3 on image binary 420: on the edge of the image
# Cell 1 on image binary 428: on the edge of the image
# Cell 1 on image binary 430: on the edge of the image
# Cell 2 on image binary 433: on the edge of the image
# Cell 7 on image binary 438: on the edge of the image
# Cell 5 on image binary 440: on the edge of the image
# Cell 8 on image binary 441: on the edge of the image
# Cell 1 on image binary 444: on the edge of the image
# Cell 3 on image binary 453: on the edge of the image
# Cell 1 on image binary 457: on the edge of the image
# Cell 9 on image binary 461: on the edge of the image
# Image binary 464: No cells
# Cell 2 on image binary 465: on the edge of the image
# Cell 5 on image binary 468: on the edge of the image
# Cell 1 on image binary 472: on the edge of the image
# Cell 3 on image binary 472: on the edge of the image
# Cell 1 on image binary 474: on the edge of the image
# Cell 5 on image binary 475: on the edge of the image
# Cell 1 on image binary 484: on the edge of the image
# Cell 1 on image binary 493: on the edge of the image
# Cell 5 on image binary 495: on the edge of the image
# Cell 1 on image binary 501: on the edge of the image
# Image binary 502: No cells
# Image binary 503: No cells
# Image binary 505: No cells
# Cell 1 on image binary 527: on the edge of the image
# Cell 5 on image binary 532: on the edge of the image
# Cell 1 on image binary 538: on the edge of the image
# Cell 3 on image binary 541: on the edge of the image
# Cell 4 on image binary 547: on the edge of the image
# Cell 1 on image binary 552: on the edge of the image
# Cell 3 on image binary 552: on the edge of the image
# Cell 1 on image binary 555: on the edge of the image
# Cell 8 on image binary 557: on the edge of the image
# Cell 1 on image binary 566: on the edge of the image
# Cell 2 on image binary 567: on the edge of the image
# Cell 1 on image binary 569: on the edge of the image
# Cell 1 on image binary 573: on the edge of the image
# Cell 1 on image binary 574: on the edge of the image
# Cell 1 on image binary 575: on the edge of the image
# Cell 4 on image binary 580: on the edge of the image
# Cell 5 on image binary 592: on the edge of the image
# Cell 6 on image binary 606: on the edge of the image
# Cell 6 on image binary 621: on the edge of the image
# Cell 3 on image binary 633: on the edge of the image
# Cell 2 on image binary 634: on the edge of the image
# Cell 1 on image binary 635: on the edge of the image
# Cell 4 on image binary 636: on the edge of the image
# Cell 1 on image binary 637: on the edge of the image
# Cell 9 on image binary 639: on the edge of the image
# Cell 1 on image binary 646: on the edge of the image
# Cell 4 on image binary 650: on the edge of the image
# Cell 4 on image binary 655: on the edge of the image
# Cell 8 on image binary 657: on the edge of the image
# Cell 3 on image binary 659: on the edge of the image
# Cell 4 on image binary 663: on the edge of the image
# Cell 1 on image binary 672: on the edge of the image
# Cell 7 on image binary 674: on the edge of the image
# Cell 6 on image binary 675: on the edge of the image
# Cell 5 on image binary 688: on the edge of the image
# Cell 2 on image binary 696: on the edge of the image
# Cell 4 on image binary 706: on the edge of the image
# Cell 5 on image binary 712: on the edge of the image
# Cell 8 on image binary 712: on the edge of the image
# Cell 4 on image binary 714: on the edge of the image
# Cell 5 on image binary 715: on the edge of the image
# Cell 1 on image binary 723: on the edge of the image
# Cell 7 on image binary 726: on the edge of the image
# Cell 2 on image binary 728: on the edge of the image
# Cell 7 on image binary 730: on the edge of the image
# Cell 5 on image binary 731: on the edge of the image
# Cell 11 on image binary 732: on the edge of the image
# Cell 1 on image binary 742: on the edge of the image
# Cell 1 on image binary 747: on the edge of the image
# Cell 8 on image binary 750: on the edge of the image
# Cell 5 on image binary 751: on the edge of the image
# Cell 6 on image binary 753: on the edge of the image
# Cell 4 on image binary 757: on the edge of the image
# Cell 5 on image binary 761: on the edge of the image
# Cell 2 on image binary 764: on the edge of the image
# Cell 1 on image binary 765: on the edge of the image
# Cell 1 on image binary 768: on the edge of the image
# Cell 1 on image binary 771: on the edge of the image
# Cell 3 on image binary 781: on the edge of the image
# Cell 1 on image binary 786: on the edge of the image
# Image binary 789: No cells
# Cell 1 on image binary 792: on the edge of the image
# Cell 4 on image binary 795: on the edge of the image
# Cell 6 on image binary 799: on the edge of the image
# Cell 1 on image binary 804: on the edge of the image
# Cell 1 on image binary 805: on the edge of the image
# Image binary 811: No cells
# Cell 2 on image binary 813: on the edge of the image
# Cell 3 on image binary 828: on the edge of the image
# Cell 3 on image binary 830: on the edge of the image
# Cell 3 on image binary 832: on the edge of the image
# Cell 5 on image binary 833: on the edge of the image
# Cell 1 on image binary 838: on the edge of the image
# Cell 5 on image binary 845: on the edge of the image
# Cell 1 on image binary 851: on the edge of the image
# Cell 2 on image binary 851: on the edge of the image
# Cell 3 on image binary 852: on the edge of the image
# Cell 8 on image binary 853: on the edge of the image
# Image binary 860: No cells
# Image binary 862: No cells
# Image binary 865: No cells
# Cell 9 on image binary 869: on the edge of the image
# Cell 1 on image binary 874: on the edge of the image
# Image binary 880: No cells
# Cell 4 on image binary 888: on the edge of the image
# Cell 1 on image binary 899: on the edge of the image
# Image binary 901: No cells
# Cell 4 on image binary 905: on the edge of the image
# Cell 1 on image binary 917: on the edge of the image
# Cell 2 on image binary 935: on the edge of the image
# Cell 1 on image binary 942: on the edge of the image
# Cell 4 on image binary 942: on the edge of the image
# Cell 1 on image binary 975: on the edge of the image

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(dd.bf)
ax2.iter_imshow(dd.b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
len(dd.cells)
# Out:
# 3055

# %%
aicp = AutoIterCellPlot(dd.cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
save(f + '_cell_raw.hdf5', dd.cells)
