# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from colicoords.preprocess import data_to_cells, filter_binaries
from colicoords import Data, iter_subplots, CellListPlot, IterCellPlot, AutoIterCellPlot, save
import os
import mahotas as mh

# %%
import colicoords
colicoords.__file__
# Out:
# 'C:\\Users\\jhs\\Programming\\cc_master\\colicoords\\__init__.py'

# %%
#input_dir = r'F:\_processed_big\t3ss\20191002_deltaescv_c41_eyfp-escv_repeat_03'
input_dir = r'H:\20191005_c41_eyfp-escv_AHT30_repeats'

# %%
c41_bf = np.load(os.path.join(input_dir, 'BF_C41_02_flat.npy'))
c41_bin = np.load(os.path.join(input_dir, 'c41_02_segmented.npy'))
c41_g100 = np.load(os.path.join(input_dir, 'c41_repeat_02_514_g100.npy'))
c41_g500 = np.load(os.path.join(input_dir, 'c41_repeat_02_514_g500.npy'))

# %%
c41_g500.shape
# Out:
# (58, 512, 512)

# %%
c41_b_filter = filter_binaries(c41_bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(c41_b_filter, 'binary')
data.add_data(c41_bf, 'brightfield')
data.add_data(c41_g100, 'fluorescence', 'g100')
data.add_data(c41_g500, 'fluorescence', 'g500')

# %%
cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Cell 5 on image binary 24: on the edge of the image
# Cell 1 on image binary 30: on the edge of the image
# Cell 6 on image binary 56: on the edge of the image

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(c41_bf)
ax2.iter_imshow(c41_b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
len(cells)
# Out:
# 213

# %%
aicp = AutoIterCellPlot(cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
save('c41_02_cell_raw.hdf5', cells)

# %%
c41_03_bf = np.load(os.path.join(input_dir, 'BF_C41_03_flat.npy'))
c41_03_bin = np.load(os.path.join(input_dir, 'c41_03_segmented.npy'))
c41_03_g100 = np.load(os.path.join(input_dir, 'c41_repeat_03_514_g100.npy'))
c41_03_g500 = np.load(os.path.join(input_dir, 'c41_repeat_03_514_g500.npy'))

# %%
c41_03_b_filter = filter_binaries(c41_03_bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(c41_03_b_filter, 'binary')
data.add_data(c41_03_bf, 'brightfield')
data.add_data(c41_03_g100, 'fluorescence', 'g100')
data.add_data(c41_03_g500, 'fluorescence', 'g500')

# %%
cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Cell 3 on image binary 5: on the edge of the image
# Image binary 16: No cells
# Image binary 19: No cells
# Cell 1 on image binary 26: on the edge of the image
# Cell 1 on image binary 31: on the edge of the image
# Image binary 39: No cells
# Image binary 40: No cells
# Image binary 41: No cells
# Image binary 53: No cells
# Cell 1 on image binary 57: on the edge of the image
# Image binary 62: No cells
# Cell 6 on image binary 65: on the edge of the image
# Cell 1 on image binary 67: on the edge of the image
# Image binary 73: No cells
# Image binary 81: No cells
# Image binary 84: No cells
# Cell 4 on image binary 95: on the edge of the image
# Image binary 102: No cells
# Image binary 106: No cells
# Cell 2 on image binary 114: on the edge of the image
# Image binary 120: No cells
# Image binary 124: No cells
# Cell 3 on image binary 127: on the edge of the image
# Image binary 130: No cells
# Image binary 137: No cells
# Image binary 142: No cells
# Cell 2 on image binary 144: on the edge of the image
# Cell 1 on image binary 154: on the edge of the image
# Image binary 158: No cells
# Image binary 159: No cells
# Image binary 162: No cells
# Image binary 169: No cells
# Image binary 177: No cells
# Cell 1 on image binary 182: on the edge of the image
# Image binary 189: No cells
# Image binary 198: No cells
# Image binary 199: No cells
# Cell 1 on image binary 210: on the edge of the image
# Image binary 213: No cells
# Image binary 214: No cells
# Cell 1 on image binary 216: on the edge of the image
# Image binary 222: No cells
# Image binary 226: No cells
# Image binary 231: No cells
# Image binary 235: No cells
# Image binary 238: No cells
# Cell 7 on image binary 239: on the edge of the image
# Cell 2 on image binary 243: on the edge of the image
# Image binary 253: No cells
# Image binary 254: No cells
# Image binary 260: No cells
# Cell 1 on image binary 266: on the edge of the image
# Image binary 267: No cells
# Image binary 268: No cells
# Image binary 271: No cells
# Image binary 274: No cells
# Cell 1 on image binary 275: on the edge of the image
# Cell 1 on image binary 276: on the edge of the image
# Cell 1 on image binary 285: on the edge of the image
# Image binary 288: No cells
# Image binary 290: No cells
# Image binary 295: No cells
# Image binary 300: No cells
# Image binary 309: No cells
# Cell 1 on image binary 318: on the edge of the image
# Cell 4 on image binary 334: on the edge of the image
# Image binary 335: No cells
# Image binary 338: No cells
# Image binary 340: No cells
# Image binary 342: No cells
# Image binary 345: No cells
# Cell 3 on image binary 349: on the edge of the image
# Image binary 350: No cells
# Cell 1 on image binary 351: on the edge of the image
# Image binary 354: No cells
# Cell 1 on image binary 355: on the edge of the image
# Cell 4 on image binary 355: on the edge of the image
# Image binary 360: No cells
# Image binary 361: No cells
# Cell 2 on image binary 364: on the edge of the image
# Cell 2 on image binary 365: on the edge of the image
# Image binary 371: No cells
# Cell 1 on image binary 388: on the edge of the image
# Cell 4 on image binary 401: on the edge of the image
# Cell 2 on image binary 406: on the edge of the image
# Cell 2 on image binary 411: on the edge of the image
# Cell 4 on image binary 411: on the edge of the image
# Cell 4 on image binary 421: on the edge of the image
# Image binary 422: No cells
# Cell 1 on image binary 424: on the edge of the image
# Cell 5 on image binary 424: on the edge of the image
# Cell 2 on image binary 426: on the edge of the image
# Image binary 430: No cells
# Cell 4 on image binary 431: on the edge of the image
# Cell 8 on image binary 434: on the edge of the image
# Cell 1 on image binary 440: on the edge of the image
# Cell 4 on image binary 445: on the edge of the image
# Image binary 455: No cells
# Cell 2 on image binary 458: on the edge of the image
# Image binary 467: No cells
# Image binary 469: No cells
# Image binary 470: No cells
# Image binary 473: No cells
# Cell 2 on image binary 477: on the edge of the image
# Cell 4 on image binary 479: on the edge of the image
# Image binary 480: No cells
# Image binary 482: No cells
# Image binary 490: No cells
# Image binary 491: No cells
# Image binary 495: No cells
# Cell 1 on image binary 508: on the edge of the image
# Cell 3 on image binary 509: on the edge of the image
# Cell 1 on image binary 511: on the edge of the image
# Cell 1 on image binary 512: on the edge of the image
# Image binary 513: No cells
# Cell 2 on image binary 519: on the edge of the image
# Cell 3 on image binary 519: on the edge of the image
# Cell 6 on image binary 519: on the edge of the image
# Cell 7 on image binary 525: on the edge of the image
# Cell 5 on image binary 534: on the edge of the image
# Cell 1 on image binary 535: on the edge of the image
# Cell 3 on image binary 535: on the edge of the image
# Cell 5 on image binary 535: on the edge of the image
# Cell 2 on image binary 541: on the edge of the image
# Cell 2 on image binary 542: on the edge of the image
# Cell 6 on image binary 543: on the edge of the image
# Cell 2 on image binary 554: on the edge of the image
# Image binary 560: No cells
# Cell 3 on image binary 561: on the edge of the image
# Cell 1 on image binary 562: on the edge of the image
# Cell 4 on image binary 566: on the edge of the image
# Image binary 587: No cells
# Image binary 588: No cells
# Image binary 589: No cells
# Cell 5 on image binary 592: on the edge of the image
# Image binary 596: No cells
# Image binary 599: No cells
# Image binary 601: No cells
# Image binary 602: No cells
# Image binary 603: No cells
# Image binary 605: No cells
# Image binary 606: No cells
# Image binary 607: No cells
# Image binary 609: No cells
# Image binary 610: No cells
# Image binary 614: No cells
# Image binary 615: No cells
# Image binary 617: No cells
# Image binary 618: No cells
# Image binary 620: No cells
# Image binary 621: No cells
# Image binary 625: No cells
# Image binary 627: No cells
# Image binary 628: No cells
# Image binary 629: No cells
# Image binary 630: No cells
# Image binary 632: No cells
# Image binary 637: No cells
# Image binary 638: No cells
# Image binary 640: No cells
# Image binary 641: No cells
# Image binary 649: No cells
# Image binary 660: No cells
# Image binary 663: No cells
# 664 1
# Image binary 667: No cells
# Cell 1 on image binary 672: on the edge of the image
# Image binary 673: No cells
# Image binary 676: No cells
# Image binary 679: No cells
# Image binary 680: No cells
# Image binary 684: No cells
# Image binary 687: No cells
# Image binary 689: No cells
# Image binary 702: No cells
# Image binary 703: No cells
# Image binary 704: No cells
# Image binary 705: No cells
# Image binary 706: No cells
# Image binary 707: No cells
# Image binary 708: No cells
# Image binary 709: No cells
# Image binary 710: No cells
# Image binary 711: No cells
# Image binary 712: No cells
# Image binary 713: No cells
# Image binary 714: No cells
# Image binary 715: No cells
# Image binary 719: No cells
# Image binary 720: No cells
# Image binary 721: No cells
# Image binary 722: No cells
# Image binary 723: No cells
# Image binary 725: No cells
# Cell 2 on image binary 727: on the edge of the image
# Image binary 731: No cells
# Image binary 736: No cells
# Image binary 741: No cells
# Image binary 746: No cells
# Image binary 747: No cells
# Image binary 749: No cells
# Cell 1 on image binary 752: on the edge of the image
# Image binary 754: No cells
# Image binary 770: No cells
# Cell 5 on image binary 771: on the edge of the image
# Image binary 773: No cells
# Image binary 774: No cells
# Image binary 779: No cells
# Cell 3 on image binary 781: on the edge of the image
# Cell 4 on image binary 781: on the edge of the image
# Image binary 783: No cells
# Image binary 785: No cells
# Image binary 788: No cells
# Cell 1 on image binary 789: on the edge of the image
# Image binary 790: No cells
# Image binary 791: No cells
# Image binary 806: No cells
# Image binary 808: No cells
# Image binary 809: No cells
# Image binary 815: No cells
# Image binary 820: No cells
# Image binary 826: No cells
# Image binary 827: No cells
# Image binary 828: No cells
# Image binary 829: No cells
# Image binary 830: No cells
# Image binary 831: No cells
# Image binary 833: No cells
# Image binary 835: No cells
# Image binary 836: No cells
# Image binary 837: No cells
# Image binary 838: No cells
# Image binary 840: No cells
# Image binary 841: No cells
# Image binary 842: No cells
# Image binary 843: No cells
# Image binary 844: No cells
# Image binary 847: No cells
# Cell 1 on image binary 849: on the edge of the image
# Image binary 850: No cells
# Image binary 851: No cells
# Image binary 852: No cells
# Image binary 853: No cells
# Image binary 854: No cells
# Image binary 855: No cells
# Image binary 856: No cells
# Image binary 858: No cells
# Image binary 859: No cells
# Image binary 860: No cells
# Image binary 861: No cells
# Image binary 862: No cells
# Image binary 863: No cells
# Image binary 864: No cells
# Image binary 865: No cells
# Image binary 866: No cells
# Image binary 867: No cells
# Image binary 868: No cells
# Image binary 869: No cells
# Image binary 870: No cells
# Image binary 871: No cells
# Image binary 872: No cells
# Image binary 873: No cells
# Image binary 874: No cells
# Image binary 875: No cells
# Image binary 876: No cells
# Image binary 877: No cells
# Image binary 879: No cells
# Image binary 880: No cells
# Image binary 881: No cells
# Image binary 882: No cells
# Image binary 883: No cells
# Image binary 884: No cells
# Image binary 885: No cells
# Image binary 886: No cells
# Image binary 887: No cells
# Image binary 888: No cells
# Image binary 889: No cells
# Image binary 890: No cells
# Image binary 891: No cells
# Image binary 893: No cells
# Image binary 894: No cells
# Image binary 895: No cells
# Image binary 896: No cells
# Image binary 897: No cells
# Image binary 898: No cells
# Image binary 899: No cells
# Image binary 902: No cells
# Cell 1 on image binary 906: on the edge of the image
# Image binary 908: No cells
# Image binary 914: No cells
# Image binary 916: No cells
# Image binary 917: No cells
# Image binary 918: No cells
# Image binary 919: No cells
# Image binary 920: No cells
# Image binary 921: No cells
# Image binary 923: No cells
# Image binary 925: No cells
# Image binary 926: No cells
# Image binary 927: No cells
# Image binary 930: No cells
# Image binary 931: No cells
# Image binary 935: No cells
# Image binary 938: No cells
# Image binary 939: No cells
# Image binary 944: No cells
# Image binary 946: No cells
# Image binary 947: No cells
# Image binary 948: No cells
# Image binary 949: No cells
# Image binary 950: No cells
# Image binary 952: No cells
# Image binary 954: No cells
# Image binary 955: No cells
# Image binary 956: No cells
# Image binary 957: No cells
# Image binary 958: No cells
# Image binary 959: No cells
# Image binary 960: No cells
# Image binary 961: No cells
# Image binary 962: No cells
# Image binary 963: No cells
# Image binary 964: No cells
# Image binary 965: No cells
# Image binary 966: No cells
# Image binary 967: No cells
# Image binary 968: No cells
# Image binary 969: No cells
# Image binary 970: No cells
# Image binary 971: No cells
# Image binary 972: No cells
# Image binary 973: No cells
# Image binary 974: No cells
# Image binary 975: No cells
# Image binary 976: No cells
# Image binary 977: No cells
# Image binary 978: No cells
# Image binary 979: No cells
# Image binary 981: No cells
# Image binary 982: No cells
# Image binary 983: No cells
# Image binary 985: No cells
# Image binary 986: No cells
# Image binary 987: No cells
# Image binary 988: No cells
# Image binary 989: No cells
# Image binary 990: No cells
# Image binary 991: No cells
# Image binary 992: No cells
# Image binary 993: No cells
# Image binary 994: No cells
# Image binary 995: No cells
# Image binary 996: No cells
# Image binary 997: No cells
# Image binary 998: No cells
# Image binary 999: No cells
# Cell 2 on image binary 1004: on the edge of the image
# Image binary 1006: No cells
# Image binary 1016: No cells
# Image binary 1017: No cells
# Cell 1 on image binary 1022: on the edge of the image
# Image binary 1023: No cells
# Image binary 1041: No cells
# Image binary 1043: No cells
# Image binary 1046: No cells
# Image binary 1050: No cells
# Image binary 1053: No cells
# Image binary 1054: No cells
# Cell 1 on image binary 1055: on the edge of the image
# Image binary 1065: No cells
# Image binary 1066: No cells
# Image binary 1067: No cells
# Image binary 1071: No cells
# Image binary 1076: No cells
# Image binary 1084: No cells
# Cell 2 on image binary 1086: on the edge of the image
# Image binary 1090: No cells
# Image binary 1092: No cells
# Image binary 1100: No cells
# Image binary 1102: No cells
# Image binary 1104: No cells
# Image binary 1108: No cells
# Cell 4 on image binary 1112: on the edge of the image
# Image binary 1114: No cells
# Cell 2 on image binary 1117: on the edge of the image
# Image binary 1121: No cells
# Cell 1 on image binary 1123: on the edge of the image
# Cell 1 on image binary 1131: on the edge of the image
# Image binary 1133: No cells
# Image binary 1135: No cells
# Cell 1 on image binary 1136: on the edge of the image
# Image binary 1137: No cells
# Image binary 1140: No cells
# Image binary 1141: No cells
# Image binary 1142: No cells
# Image binary 1144: No cells
# Cell 1 on image binary 1145: on the edge of the image
# Image binary 1149: No cells
# Image binary 1150: No cells
# Image binary 1152: No cells
# Image binary 1153: No cells
# Cell 5 on image binary 1156: on the edge of the image
# Image binary 1160: No cells
# Image binary 1174: No cells
# Image binary 1175: No cells
# Image binary 1179: No cells
# Image binary 1180: No cells
# Image binary 1187: No cells
# Image binary 1188: No cells
# Cell 2 on image binary 1201: on the edge of the image
# Image binary 1204: No cells
# Image binary 1205: No cells
# Image binary 1206: No cells
# Image binary 1208: No cells
# Image binary 1209: No cells
# Image binary 1211: No cells
# Image binary 1212: No cells
# Image binary 1214: No cells
# Image binary 1215: No cells
# Image binary 1216: No cells
# Image binary 1217: No cells
# Image binary 1219: No cells
# Image binary 1220: No cells
# Cell 1 on image binary 1223: on the edge of the image
# Image binary 1228: No cells
# Image binary 1229: No cells
# Cell 5 on image binary 1231: on the edge of the image
# Image binary 1232: No cells
# Image binary 1234: No cells
# Image binary 1246: No cells
# Image binary 1252: No cells
# Image binary 1253: No cells
# Image binary 1259: No cells
# Cell 4 on image binary 1262: on the edge of the image
# Cell 2 on image binary 1266: on the edge of the image
# Image binary 1282: No cells
# Image binary 1287: No cells
# Image binary 1290: No cells
# Image binary 1300: No cells
# Cell 3 on image binary 1302: on the edge of the image
# Image binary 1303: No cells
# Image binary 1304: No cells
# Image binary 1305: No cells
# Image binary 1306: No cells
# Image binary 1307: No cells
# Image binary 1308: No cells
# Image binary 1309: No cells
# Image binary 1310: No cells
# Image binary 1314: No cells
# Image binary 1317: No cells
# Image binary 1318: No cells
# Image binary 1319: No cells
# Image binary 1322: No cells
# Image binary 1326: No cells
# Cell 1 on image binary 1335: on the edge of the image
# Image binary 1341: No cells
# Cell 1 on image binary 1348: on the edge of the image
# Cell 3 on image binary 1348: on the edge of the image
# Image binary 1354: No cells
# Image binary 1356: No cells
# Image binary 1358: No cells
# 1359 1
# Image binary 1360: No cells
# Image binary 1364: No cells
# Cell 2 on image binary 1367: on the edge of the image
# Cell 3 on image binary 1370: on the edge of the image
# Image binary 1373: No cells
# Image binary 1378: No cells
# Image binary 1385: No cells
# Image binary 1390: No cells
# Image binary 1398: No cells
# Image binary 1399: No cells

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(c41_03_bf)
ax2.iter_imshow(c41_03_b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
len(cells)
# Out:
# 2342

# %%
aicp = AutoIterCellPlot(cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
save('c41_03_cell_raw.hdf5', cells)
