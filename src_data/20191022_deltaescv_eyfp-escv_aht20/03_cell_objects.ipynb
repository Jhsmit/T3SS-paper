# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from colicoords.preprocess import data_to_cells, filter_binaries
from colicoords import Data, iter_subplots, CellListPlot, IterCellPlot, AutoIterCellPlot, save
import os
import mahotas as mh
from addict import Dict
# Out:
# Warning: Version number not found.

# %%
import colicoords
colicoords.__file__
# Out:
# 'C:\\Users\\jhs\\Programming\\cc_master\\colicoords\\__init__.py'

# %%
#input_dir = r'F:\_processed_big\t3ss\20191002_deltaescv_c41_eyfp-escv_repeat_03'
input_dir = r'I:\20191022_deltaescv_eyfp-escv_aht20'

# %% [markdown]
# # 20191022_deltaescv_eyfp-escv_aht20

# %%
dd = Dict()
f = 'epec_yfp-escv_aht20'

# %%
dd.bf = np.load(os.path.join(input_dir, f + '_BF_flat.npy'))
dd.bin = np.load(os.path.join(input_dir, f + '_segmented.npy'))
dd.g100 = np.load(os.path.join(input_dir, f + '_514_g100.npy'))
dd.g500 = np.load(os.path.join(input_dir, f + '_514_g500.npy'))

# %%
dd.bf.shape
# Out:
# (51, 512, 512)

# %%
dd.b_filter = filter_binaries(dd.bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(dd.b_filter, 'binary')
data.add_data(dd.bf, 'brightfield')
data.add_data(dd.g100, 'fluorescence', 'g100')
data.add_data(dd.g500, 'fluorescence', 'g500')

# %%
dd.cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Cell 7 on image binary 41: on the edge of the image

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(dd.bf)
ax2.iter_imshow(dd.b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
len(dd.cells)
# Out:
# 220

# %%
aicp = AutoIterCellPlot(dd.cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
save(f + '_cell_raw.hdf5', dd.cells)

# %%
dd.bf.shape
# Out:
# (1000, 512, 512)

# %%
dd.b_filter = filter_binaries(dd.bin, min_size=200, max_size=10000, min_minor=6, max_minor=11, min_major=10, max_major=100)

# %%
data = Data()
data.add_data(dd.b_filter, 'binary')
data.add_data(dd.bf, 'brightfield')
data.add_data(dd.g100, 'fluorescence', 'g100')
data.add_data(dd.g500, 'fluorescence', 'g500')

# %%
dd.cells = data_to_cells(data, remove_multiple_cells=False)
# Out:
# Image binary 1: No cells
# Image binary 2: No cells
# Image binary 4: No cells
# Image binary 5: No cells
# Image binary 6: No cells
# Image binary 7: No cells
# Image binary 12: No cells
# Image binary 13: No cells
# Image binary 16: No cells
# Image binary 17: No cells
# Image binary 21: No cells
# Image binary 23: No cells
# Image binary 24: No cells
# Image binary 33: No cells
# Image binary 36: No cells
# Image binary 37: No cells
# Image binary 42: No cells
# Image binary 47: No cells
# Image binary 50: No cells
# Image binary 59: No cells
# Image binary 60: No cells
# Image binary 71: No cells
# Image binary 72: No cells
# Image binary 76: No cells
# Image binary 77: No cells
# Image binary 80: No cells
# Image binary 81: No cells
# Image binary 82: No cells
# Image binary 88: No cells
# Image binary 89: No cells
# Image binary 90: No cells
# Image binary 92: No cells
# Image binary 93: No cells
# Image binary 94: No cells
# Image binary 96: No cells
# Image binary 110: No cells
# Image binary 116: No cells
# Image binary 117: No cells
# Image binary 120: No cells
# Image binary 123: No cells
# Cell 1 on image binary 124: on the edge of the image
# Image binary 127: No cells
# Image binary 132: No cells
# Cell 2 on image binary 134: on the edge of the image
# Image binary 135: No cells
# Image binary 136: No cells
# Image binary 138: No cells
# Image binary 143: No cells
# Image binary 145: No cells
# Image binary 146: No cells
# Image binary 149: No cells
# Cell 4 on image binary 154: on the edge of the image
# Image binary 160: No cells
# Image binary 162: No cells
# Image binary 163: No cells
# Cell 1 on image binary 166: on the edge of the image
# Image binary 167: No cells
# Image binary 171: No cells
# Image binary 172: No cells
# Image binary 174: No cells
# Image binary 175: No cells
# Image binary 176: No cells
# Image binary 177: No cells
# Image binary 181: No cells
# Image binary 182: No cells
# Image binary 183: No cells
# Image binary 186: No cells
# Image binary 187: No cells
# Image binary 189: No cells
# Image binary 190: No cells
# Image binary 192: No cells
# Image binary 193: No cells
# Image binary 194: No cells
# Image binary 195: No cells
# Image binary 196: No cells
# Image binary 198: No cells
# Image binary 202: No cells
# Image binary 205: No cells
# Image binary 206: No cells
# Image binary 208: No cells
# Image binary 209: No cells
# Image binary 212: No cells
# Image binary 215: No cells
# Image binary 220: No cells
# Image binary 223: No cells
# Cell 2 on image binary 228: on the edge of the image
# Image binary 231: No cells
# Image binary 236: No cells
# Cell 1 on image binary 242: on the edge of the image
# Cell 1 on image binary 244: on the edge of the image
# Image binary 246: No cells
# Cell 3 on image binary 249: on the edge of the image
# Image binary 250: No cells
# Image binary 254: No cells
# Image binary 261: No cells
# Image binary 263: No cells
# Image binary 266: No cells
# Image binary 267: No cells
# Image binary 268: No cells
# Image binary 269: No cells
# Image binary 270: No cells
# Image binary 271: No cells
# Image binary 272: No cells
# Image binary 273: No cells
# Image binary 275: No cells
# Image binary 276: No cells
# Image binary 280: No cells
# Image binary 281: No cells
# Image binary 282: No cells
# Cell 1 on image binary 283: on the edge of the image
# Image binary 284: No cells
# Image binary 285: No cells
# Image binary 286: No cells
# Image binary 287: No cells
# Image binary 288: No cells
# Image binary 289: No cells
# Image binary 290: No cells
# Image binary 291: No cells
# Image binary 292: No cells
# Image binary 293: No cells
# Image binary 294: No cells
# Image binary 295: No cells
# Image binary 296: No cells
# Image binary 297: No cells
# Image binary 298: No cells
# Image binary 299: No cells
# Image binary 300: No cells
# Image binary 301: No cells
# Image binary 302: No cells
# Image binary 303: No cells
# Image binary 305: No cells
# Image binary 306: No cells
# Image binary 307: No cells
# Image binary 311: No cells
# Image binary 313: No cells
# Image binary 317: No cells
# Cell 1 on image binary 318: on the edge of the image
# Image binary 320: No cells
# Cell 4 on image binary 321: on the edge of the image
# Cell 3 on image binary 322: on the edge of the image
# Cell 1 on image binary 323: on the edge of the image
# Image binary 324: No cells
# Image binary 329: No cells
# Cell 2 on image binary 330: on the edge of the image
# Image binary 335: No cells
# Image binary 336: No cells
# Image binary 340: No cells
# Cell 1 on image binary 349: on the edge of the image
# Cell 3 on image binary 349: on the edge of the image
# Image binary 350: No cells
# Image binary 351: No cells
# Image binary 355: No cells
# Image binary 356: No cells
# Image binary 357: No cells
# Image binary 358: No cells
# Image binary 360: No cells
# Image binary 361: No cells
# Image binary 362: No cells
# Image binary 363: No cells
# Image binary 364: No cells
# Image binary 365: No cells
# Image binary 366: No cells
# Image binary 368: No cells
# Cell 1 on image binary 369: on the edge of the image
# Image binary 370: No cells
# Image binary 371: No cells
# Image binary 372: No cells
# Cell 1 on image binary 373: on the edge of the image
# Image binary 374: No cells
# Image binary 375: No cells
# Image binary 376: No cells
# Image binary 377: No cells
# Image binary 378: No cells
# Image binary 379: No cells
# Image binary 380: No cells
# Image binary 381: No cells
# Image binary 382: No cells
# Image binary 384: No cells
# Image binary 385: No cells
# Image binary 386: No cells
# Image binary 387: No cells
# Image binary 388: No cells
# Image binary 389: No cells
# Image binary 390: No cells
# Image binary 391: No cells
# Image binary 392: No cells
# Image binary 393: No cells
# Image binary 394: No cells
# Image binary 395: No cells
# Image binary 396: No cells
# Image binary 397: No cells
# Image binary 398: No cells
# Image binary 399: No cells
# Image binary 402: No cells
# Image binary 403: No cells
# Image binary 404: No cells
# Image binary 406: No cells
# Image binary 409: No cells
# Cell 1 on image binary 417: on the edge of the image
# Cell 2 on image binary 417: on the edge of the image
# Cell 7 on image binary 419: on the edge of the image
# Image binary 424: No cells
# Image binary 425: No cells
# Image binary 430: No cells
# Image binary 432: No cells
# Image binary 434: No cells
# Image binary 438: No cells
# Image binary 439: No cells
# Image binary 440: No cells
# Image binary 441: No cells
# Cell 1 on image binary 442: on the edge of the image
# Image binary 443: No cells
# Image binary 444: No cells
# Image binary 448: No cells
# Image binary 450: No cells
# Image binary 454: No cells
# Image binary 460: No cells
# Image binary 464: No cells
# Cell 3 on image binary 468: on the edge of the image
# Image binary 470: No cells
# Image binary 472: No cells
# Image binary 474: No cells
# Image binary 479: No cells
# Image binary 481: No cells
# Image binary 482: No cells
# Image binary 483: No cells
# Image binary 484: No cells
# Image binary 485: No cells
# Image binary 486: No cells
# Image binary 487: No cells
# Image binary 490: No cells
# Image binary 491: No cells
# Image binary 493: No cells
# Image binary 494: No cells
# Image binary 495: No cells
# Image binary 496: No cells
# Image binary 497: No cells
# Image binary 499: No cells
# Image binary 500: No cells
# Image binary 501: No cells
# Image binary 502: No cells
# Image binary 503: No cells
# Cell 4 on image binary 506: on the edge of the image
# Image binary 512: No cells
# Image binary 515: No cells
# Image binary 519: No cells
# Image binary 533: No cells
# Image binary 534: No cells
# Image binary 537: No cells
# Image binary 539: No cells
# Image binary 543: No cells
# Image binary 547: No cells
# Image binary 549: No cells
# Image binary 552: No cells
# Image binary 556: No cells
# Image binary 557: No cells
# Image binary 558: No cells
# Image binary 560: No cells
# Image binary 562: No cells
# Image binary 568: No cells
# Image binary 569: No cells
# Image binary 573: No cells
# Image binary 574: No cells
# Image binary 576: No cells
# Image binary 577: No cells
# Image binary 578: No cells
# Image binary 579: No cells
# Image binary 580: No cells
# Image binary 581: No cells
# Image binary 583: No cells
# Image binary 584: No cells
# Image binary 585: No cells
# Image binary 588: No cells
# Image binary 589: No cells
# Image binary 593: No cells
# Image binary 594: No cells
# Image binary 595: No cells
# Image binary 596: No cells
# Image binary 597: No cells
# Image binary 598: No cells
# Image binary 599: No cells
# Cell 13 on image binary 605: on the edge of the image
# Cell 4 on image binary 620: on the edge of the image
# Cell 1 on image binary 621: on the edge of the image
# Cell 5 on image binary 624: on the edge of the image
# Cell 2 on image binary 632: on the edge of the image
# Image binary 634: No cells
# Image binary 636: No cells
# Cell 3 on image binary 637: on the edge of the image
# Cell 2 on image binary 645: on the edge of the image
# Image binary 646: No cells
# Cell 8 on image binary 655: on the edge of the image
# Cell 7 on image binary 661: on the edge of the image
# Cell 2 on image binary 663: on the edge of the image
# Cell 1 on image binary 683: on the edge of the image
# Cell 2 on image binary 699: on the edge of the image
# Cell 1 on image binary 708: on the edge of the image
# Image binary 709: No cells
# Cell 2 on image binary 713: on the edge of the image
# Image binary 715: No cells
# Cell 6 on image binary 718: on the edge of the image
# Cell 4 on image binary 723: on the edge of the image
# Cell 10 on image binary 725: on the edge of the image
# Cell 1 on image binary 727: on the edge of the image
# Cell 1 on image binary 732: on the edge of the image
# Image binary 733: No cells
# Cell 3 on image binary 739: on the edge of the image
# Cell 6 on image binary 743: on the edge of the image
# Cell 8 on image binary 747: on the edge of the image
# Cell 2 on image binary 760: on the edge of the image
# Cell 4 on image binary 761: on the edge of the image
# Cell 1 on image binary 765: on the edge of the image
# Cell 7 on image binary 769: on the edge of the image
# Cell 9 on image binary 777: on the edge of the image
# Cell 1 on image binary 790: on the edge of the image
# Cell 9 on image binary 799: on the edge of the image
# Cell 2 on image binary 801: on the edge of the image
# Cell 9 on image binary 805: on the edge of the image
# Cell 1 on image binary 809: on the edge of the image
# Image binary 813: No cells
# Image binary 814: No cells
# Image binary 815: No cells
# Image binary 816: No cells
# Image binary 817: No cells
# Image binary 818: No cells
# Image binary 819: No cells
# Cell 1 on image binary 823: on the edge of the image
# Cell 7 on image binary 823: on the edge of the image
# Cell 7 on image binary 824: on the edge of the image
# Cell 7 on image binary 834: on the edge of the image
# Cell 3 on image binary 837: on the edge of the image
# Cell 1 on image binary 840: on the edge of the image
# Image binary 843: No cells
# Cell 1 on image binary 850: on the edge of the image
# Cell 1 on image binary 854: on the edge of the image
# Cell 3 on image binary 859: on the edge of the image
# Cell 4 on image binary 866: on the edge of the image
# Cell 8 on image binary 868: on the edge of the image
# Image binary 869: No cells
# Cell 6 on image binary 879: on the edge of the image
# Cell 7 on image binary 879: on the edge of the image
# Cell 2 on image binary 882: on the edge of the image
# Image binary 883: No cells
# Image binary 891: No cells
# Image binary 894: No cells
# Image binary 895: No cells
# Image binary 896: No cells
# Cell 1 on image binary 897: on the edge of the image
# Image binary 898: No cells
# Image binary 903: No cells
# Cell 8 on image binary 909: on the edge of the image
# Cell 7 on image binary 914: on the edge of the image
# Cell 5 on image binary 916: on the edge of the image
# Cell 8 on image binary 921: on the edge of the image
# Cell 4 on image binary 922: on the edge of the image
# Cell 1 on image binary 929: on the edge of the image
# Cell 1 on image binary 930: on the edge of the image
# Image binary 931: No cells
# Cell 1 on image binary 936: on the edge of the image
# Cell 6 on image binary 943: on the edge of the image
# Cell 2 on image binary 949: on the edge of the image
# Image binary 950: No cells
# Image binary 957: No cells
# Cell 1 on image binary 971: on the edge of the image
# Cell 1 on image binary 972: on the edge of the image
# Cell 2 on image binary 975: on the edge of the image
# Image binary 980: No cells
# Cell 2 on image binary 984: on the edge of the image
# Image binary 985: No cells
# Image binary 990: No cells
# Image binary 991: No cells
# Image binary 993: No cells
# Image binary 996: No cells
# Image binary 997: No cells
# Cell 2 on image binary 998: on the edge of the image
# Cell 12 on image binary 999: on the edge of the image

# %%
fig, (ax1, ax2) = iter_subplots(1, 2)
ax1.iter_imshow(dd.bf)
ax2.iter_imshow(dd.b_filter)
fig.display()
# Out:
# <img src="data:image/png;base64,..." width="640">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
len(dd.cells)
# Out:
# 1953

# %%
aicp = AutoIterCellPlot(dd.cells)
aicp.plot()
# Out:
# <img src="data:image/png;base64,..." width="950">
# VBox(children=(HBox(children=(Button(description='First', style=ButtonStyle()), Button(description='Prev', sty…

# %%
save(f + '_cell_raw.hdf5', dd.cells)
